# %%
import pandas as pd
data = pd.read_csv("Tripadvisordata_final.csv")

data= data.round(2)

list = []
for i in range(len(data["Type of food"])):  
    if "<div" in str(data["Type of food"][i]):
        list.append(i)
    
#print(list)
for i in list:
    data["Type of food"][i] = "Missing"


# set color 
green_color = "#00AF87"
# Out:
# C:\Users\rhs\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
data.head()
# Out:
#                   Restaurant  Main rating  Ranking on list Price range  \
# 0                Burger King          1.0           2148.0         NaN
# 1                    Almanac          1.0           2146.0         NaN
# 2  Star Midnight Kebab-Grill          1.0           2143.0         101
# 3           Sunset Boulevard          1.0           2137.0         NaN
# 4  Dwaraka Indisk Restaurant          1.0           2104.0         141
#
#    Price class            Location  Good price  Food  Service  Atmosphere  \
# 0     --$$$$$$   55.65107,12.50931         NaN   NaN      NaN         NaN
# 1          ---  55.67788,12.591933         NaN   NaN      NaN         NaN
# 2  --$$-$$$---    55.6679,12.54941         NaN   NaN      NaN         NaN
# 3     --$$$$$$  55.67502,12.580593         NaN   NaN      NaN         NaN
# 4  --$$-$$$---  55.72732,12.524776         NaN   NaN      NaN         NaN
#
#   Type of food  Number of reviews  \
# 0          NaN                2.0
# 1        Dansk                2.0
# 2        Grill                3.0
# 3          NaN                2.0
# 4       Indisk                1.0
#
#                                             Address  \
# 0          Ellebjergvej 142, København 2450 Danmark
# 1                   Havnegade 44, København Danmark
# 2                  Istedgade 101, København Danmark
# 3  Københavns Hovedbanegård, København 1570 Danmark
# 4  Frederiksborgvej 221, St, København 2860 Danmark
#
#                                    Type of food link New price class  \
# 0                                                NaN          $$$$$$
# 1  <div class="header_links"><a href="/Restaurant...          $$$$$$
# 2  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 3                                                NaN          $$$$$$
# 4  <div class="header_links"><a href="/Restaurant...          $$-$$$
#
#    Price class numeric  Reverse ranking on list  Full ranking  \
# 0                   99                  -2148.0             1
# 1                   99                  -2146.0             2
# 2                    2                  -2143.0             3
# 3                   99                  -2137.0             4
# 4                    2                  -2104.0             5
#
#    Distance from Kgs. Nytorv (m) Postal code
# 0                          199.0       2450
# 1                          459.0
# 2                         3431.0
# 3                          908.0       1570
# 4                         1171.0       2860

# %%
sum_tab = data.describe()
sum_tab.to_csv("Summary_tab.csv")

# %%
import matplotlib.pyplot as plt

mod_df = data 

# Obs filter restaurants more than 15 km from Kgs. Nytorv
#mod_df = mod_df.drop(mod_df[mod_df[] > 15000 ].index , inplace=True)
mod_df = data[data["Distance from Kgs. Nytorv (m)"]<1000]


#mod_df.describe()
# OBS kør den forfra hvis du vil ændre i noget. 
mod_df
# Out:
#                                         Restaurant  Main rating  \
# 0                                      Burger King          1.0
# 1                                          Almanac          1.0
# 3                                 Sunset Boulevard          1.0
# 5                                       McDonald's          1.0
# 8                                           Kujaku          1.0
# 9                       Gastronomia Italiana Dieci          1.0
# 10                             Restaurant Balkonen          1.0
# 11                                     Carisma ApS          1.0
# 12                              Dan Dan Restaurant          1.5
# 14                                          Krunch          1.5
# 15                                        Yoburger          1.5
# 18                                 La Coruna Pizza          1.5
# 21                                  Kokken & Karry          1.5
# 25                                 Cafe-Pavillonen          2.0
# 26                                Tapas Revolution          2.0
# 27                                 Sushibar Fields          2.0
# 32                                 Den Sorte Gryde          2.0
# 36                                          Café A          2.0
# 37                                 Den sorte gryde          2.0
# 38                                 Joe & The Juice          2.0
# 40                                         Punjabi          2.0
# 41                                          Cocolo          2.0
# 42                                   Palermo Pizza          2.0
# 45                                   The Taco Shop          2.0
# 46    Flintholm Sushi - Running Sushi Og Take Away          2.0
# 47                                   Montgomerycph          2.0
# 51                                      City Kroen          2.5
# 52                       Nachos Mexican Restaurant          2.5
# 56                               Restaurant Parnas          2.5
# 63                                  Cph Asian Food          2.5
# ...                                            ...          ...
# 2177                                  Golden Pizza          NaN
# 2178                            Middelgrundsfortet          NaN
# 2180                                 Square Burger          NaN
# 2193                   Green Room Restaurant & Bar          NaN
# 2194                                      Pizza 13          NaN
# 2201                                    Mo's Pizza          NaN
# 2207                                Mozarts Bodega          NaN
# 2224                                 Figaros Pizza          NaN
# 2225                                    Evergreens          NaN
# 2230                            Thapa's Restaurant          NaN
# 2231                               Milano Pizzabar          NaN
# 2243                                   Sushi Style          NaN
# 2247                                        Lily’s          NaN
# 2250                              Dido Durum House          NaN
# 2255                                    Cupenhague          NaN
# 2258                             13z Cafe & Studio          NaN
# 2261                                        Barock          NaN
# 2263                                 Pasta du Nord          NaN
# 2264                               Joe & The Juice          NaN
# 2266                                      Venligbo          NaN
# 2273                                        Blasen          NaN
# 2274                                Nummer Fem CPH          NaN
# 2282                                      Poporoya          NaN
# 2284                                     Norrested          NaN
# 2285                                  Sheddy's CPH          NaN
# 2287                    Shabaz - Kaffebar & Køkken          NaN
# 2296                                Hovedindgangen          NaN
# 2297                             Cafe' PhoneDoktor          NaN
# 2303                                   Cafe Heaven          NaN
# 2308                                          Lime          NaN
#
#       Ranking on list Price range        Price class             Location  \
# 0              2148.0         NaN           --$$$$$$    55.65107,12.50931
# 1              2146.0         NaN                ---   55.67788,12.591933
# 3              2137.0         NaN           --$$$$$$   55.67502,12.580593
# 5              2103.0         NaN                ---    55.66268,12.56187
# 8              2090.0         NaN                ---  55.458576,12.183993
# 9              2085.0         NaN           --$$$$$$    55.66731,12.55365
# 10             2070.0         NaN                ---    55.67465,12.56565
# 11             2053.0         NaN                ---    55.65197,12.63984
# 12             2179.0         NaN       --$---------     55.67854,12.5755
# 14             2159.0         NaN           --$$$$$$    55.65898,12.60988
# 15             2141.0         148     --$$-$$$------   55.67945,12.580216
# 18             2115.0         NaN        --$$-$$$---    55.65042,12.52806
# 21              182.0         NaN             --$---  55.674896,12.533771
# 25             2171.0         NaN           --$$$$$$    55.70091,12.56682
# 26             2170.0         249        --$$-$$$---  55.670574,12.560301
# 27             2169.0         NaN  --$$-$$$---------  55.630043,12.577994
# 32             2153.0         101        --$$-$$$---    55.69068,12.48772
# 36             2139.0         NaN           --$$$$$$    55.70599,12.57588
# 37             2135.0         NaN           --$$$$$$    55.70414,12.52712
# 38             2114.0         NaN           --$$$$$$    55.67915,12.57413
# 40             2079.0         NaN                ---   55.70938,12.578384
# 41             2046.0         NaN       ------------   55.67673,12.564919
# 42             2040.0         NaN        --$$-$$$---    55.65184,12.53805
# 45              181.0         NaN             --$---     55.68425,12.5241
# 46              180.0         NaN                ---    55.68432,12.50371
# 47              177.0         NaN           --$$$$$$    55.67436,12.54965
# 51             2166.0         NaN        --$$-$$$---  55.678158,12.572339
# 52             2165.0         NaN        --$$-$$$---   55.67502,12.580593
# 56             2155.0         NaN        --$$-$$$---    55.67958,12.58358
# 63             2132.0         NaN                --$     55.67854,12.5755
# ...               ...         ...                ...                  ...
# 2177              NaN         NaN        --$$-$$$---    55.70897,12.52106
# 2178              NaN         NaN                ---     55.6803,12.58457
# 2180              NaN         128  --$$-$$$---------  55.673306,12.596321
# 2193              NaN         262  --$$-$$$---------    55.67973,12.53345
# 2194              NaN         148        --$$-$$$---     55.68324,12.5345
# 2201              NaN         NaN           --$$$$$$   55.69804,12.586795
# 2207              NaN         NaN           --$$$$$$    55.64815,12.52939
# 2224              NaN         148        --$$-$$$---    55.70975,12.56816
# 2225              NaN         NaN             ------    55.67912,12.54731
# 2230              NaN         NaN           --$$$$$$    55.65958,12.60409
# 2231              NaN         155        --$$-$$$---    55.66559,12.60964
# 2243              NaN         NaN        --$$-$$$---    55.71875,12.55557
# 2247              NaN          87                --$  55.686382,12.558297
# 2250              NaN         NaN                ---    55.68838,12.55898
# 2255              NaN         107             --$---  55.692078,12.566728
# 2258              NaN         148        --$$-$$$---    55.65729,12.62809
# 2261              NaN         NaN        --$$-$$$---    55.6808,12.587827
# 2263              NaN         NaN           --$$$$$$   55.67303,12.565549
# 2264              NaN         NaN           --$$$$$$  55.672302,12.554165
# 2266              NaN         NaN           --$$$$$$   55.66712,12.543539
# 2273              NaN         NaN           --$$$$$$    55.67886,12.57224
# 2274              NaN         101  --$$-$$$---------   55.67983,12.576352
# 2282              NaN         NaN                ---    55.68529,12.55704
# 2284              NaN         121           --$$-$$$    55.69269,12.54136
# 2285              NaN         NaN           --$$$$$$    55.69704,12.54022
# 2287              NaN         NaN                ---   55.68363,12.546305
# 2296              NaN         NaN                ---    55.67465,12.56565
# 2297              NaN         NaN             --$---    55.68536,12.56768
# 2303              NaN         302        --$$-$$$---    55.67814,12.57571
# 2308              NaN         195        --$$-$$$---    55.67592,12.56586
#
#       Good price  Food  Service  Atmosphere Type of food  Number of reviews  \
# 0            NaN   NaN      NaN         NaN          NaN                2.0
# 1            NaN   NaN      NaN         NaN        Dansk                2.0
# 3            NaN   NaN      NaN         NaN          NaN                2.0
# 5            NaN   NaN      NaN         NaN     Fastfood                1.0
# 8            NaN   NaN      NaN         NaN        Sushi                1.0
# 9            NaN   NaN      NaN         NaN          NaN                1.0
# 10           NaN   NaN      NaN         NaN        Dansk                1.0
# 11           NaN   NaN      NaN         NaN     Fastfood                1.0
# 12           1.5   2.0      1.5         1.5     Asiatisk               26.0
# 14           NaN   NaN      NaN         NaN          NaN                7.0
# 15           NaN   NaN      NaN         NaN   Amerikansk                3.0
# 18           NaN   NaN      NaN         NaN        Pizza                2.0
# 21           1.5   1.5      2.0         1.5       Indisk               17.0
# 25           NaN   NaN      NaN         NaN          NaN               11.0
# 26           2.0   2.5      2.5         NaN       Spansk               88.0
# 27           2.5   3.0      3.0         NaN     Asiatisk               31.0
# 32           2.0   2.0      2.5         NaN        Dansk               13.0
# 36           NaN   NaN      NaN         NaN          NaN                7.0
# 37           NaN   NaN      NaN         NaN        Grill                4.0
# 38           NaN   NaN      NaN         NaN          NaN                5.0
# 40           NaN   NaN      NaN         NaN       Indisk                2.0
# 41           NaN   NaN      NaN         NaN     Asiatisk                1.0
# 42           NaN   NaN      NaN         NaN        Pizza                2.0
# 45           2.0   2.0      2.5         2.5    Mexicansk               36.0
# 46           NaN   NaN      NaN         NaN        Sushi               10.0
# 47           NaN   NaN      NaN         NaN          NaN                4.0
# 51           2.5   2.5      3.0         3.0        Dansk              175.0
# 52           3.0   3.0      3.0         2.5    Mexicansk              119.0
# 56           2.5   3.0      3.0         2.5        Dansk               73.0
# 63           3.5   3.0      3.5         NaN      Missing               15.0
# ...          ...   ...      ...         ...          ...                ...
# 2177         NaN   NaN      NaN         NaN        Pizza                1.0
# 2178         NaN   NaN      NaN         NaN        Dansk                3.0
# 2180         NaN   NaN      NaN         NaN   Amerikansk                3.0
# 2193         NaN   NaN      NaN         NaN    Europæisk               12.0
# 2194         NaN   NaN      NaN         NaN        Pizza               12.0
# 2201         NaN   NaN      NaN         NaN          NaN               35.0
# 2207         NaN   NaN      NaN         NaN          NaN               69.0
# 2224         NaN   NaN      NaN         NaN        Pizza              185.0
# 2225         NaN   NaN      NaN         NaN        Dansk              186.0
# 2230         NaN   NaN      NaN         NaN          NaN              211.0
# 2231         NaN   NaN      NaN         NaN        Pizza              211.0
# 2243         NaN   NaN      NaN         NaN        Sushi              292.0
# 2247         NaN   NaN      NaN         NaN          Bar              315.0
# 2250         NaN   NaN      NaN         NaN      Tyrkisk              315.0
# 2255         NaN   NaN      NaN         NaN        Dansk              315.0
# 2258         NaN   NaN      NaN         NaN         Café              450.0
# 2261         NaN   NaN      NaN         NaN        Dansk              697.0
# 2263         NaN   NaN      NaN         NaN          NaN              705.0
# 2264         NaN   NaN      NaN         NaN          NaN              798.0
# 2266         NaN   NaN      NaN         NaN          NaN              970.0
# 2273         NaN   NaN      NaN         NaN          NaN             1085.0
# 2274         NaN   NaN      NaN         NaN         Café             1085.0
# 2282         NaN   NaN      NaN         NaN      Japansk             1248.0
# 2284         NaN   NaN      NaN         NaN      Missing             1248.0
# 2285         NaN   NaN      NaN         NaN          NaN             1248.0
# 2287         NaN   NaN      NaN         NaN        Dansk             1248.0
# 2296         NaN   NaN      NaN         NaN        Dansk             1572.0
# 2297         NaN   NaN      NaN         NaN         Café             1591.0
# 2303         NaN   NaN      NaN         NaN      Arabisk             2581.0
# 2308         NaN   NaN      NaN         NaN         Thai             3070.0
#
#                                                 Address  \
# 0              Ellebjergvej 142, København 2450 Danmark
# 1                       Havnegade 44, København Danmark
# 3      Københavns Hovedbanegård, København 1570 Danmark
# 5     Fisketorvet Shopping Center, København 1560 Da...
# 8                  Nørregade 28, København 1165 Danmark
# 9           Sønder Boulevard 40, København 1720 Danmark
# 10    Vesterbrogade 3 inside Tivoli, København 1500 ...
# 11                  Amager Strandvej, København Danmark
# 12     Vimmelskaftet 39c 1. Sal 1161, København Danmark
# 14              Oeresundsvej 14, København 2300 Danmark
# 15     Oestergade 52 Illum mall, København 1100 Danmark
# 18          Sjælør Boulevard 46, København 2450 Danmark
# 21    Frederiksberg Alle 98, Frederiksberg, Københav...
# 25         Edel Sauntes Alle 22, København 2100 Danmark
# 26                Halmtorvet 18, København 1700 Danmark
# 27    Arne Jaconsens Allé 12 Fields Shoppingcenter, ...
# 32             Jernbane Alle 79, København 2720 Danmark
# 36          Østerfælled Torv 26, København 2100 Danmark
# 37                 Frederikssundsvej, København Danmark
# 38           Skindergade 33, St, København 1159 Danmark
# 40             Strandboulevarden 168, København Danmark
# 41              Studiestræde 65, København 1154 Danmark
# 42             Borgbjergsvej 11, København 2450 Danmark
# 45    Nyelandsvej 65, Frederiksberg, København 2000 ...
# 46    Dirch Passers Allé 30, Frederiksberg, Københav...
# 47    Værnedamsvej 18, Frederiksberg, København 1619...
# 51                 Gammeltorv 8, København 1457 Danmark
# 52                            Fields, København Danmark
# 56              Lille Kongensgade 16, København Danmark
# 63            Vimmelskaftet 39C, København 1161 Danmark
# ...                                                 ...
# 2177             Smedetoften 21, København 2400 Danmark
# 2178                                                NaN
# 2180           Sydomraadet 18 A, København 1440 Danmark
# 2193  Falkoner Alle 9, Frederiksberg, København 2000...
# 2194  Rolfsvej 13, Frederiksberg, København 2000 Dan...
# 2201            Classensgade 49, København 2100 Danmark
# 2207              Mozartsvej 21, København 2450 Danmark
# 2224               Ouroegade 38, København 2100 Danmark
# 2225  H. C. Orstedsvej 50B, Frederiksberg, København...
# 2230                 Tingvej 12, København 2300 Danmark
# 2231           Holmbladsgade 58, København 2300 Danmark
# 2243                Emdrupvej 8, København 2100 Danmark
# 2247            Blågårdsgade 21, København 2200 Danmark
# 2250           Noerrebrogade 31, København 2200 Danmark
# 2255                Ryesgade 25, København 2200 Danmark
# 2258         Strandlodsvej 13-z, København 2300 Danmark
# 2261                                                NaN
# 2263  Falkoner Alle 82, Frederiksberg, København 200...
# 2264           Vesterbrogade 57, København 1620 Danmark
# 2266   Enghavevej Enghaveparken, København 1674 Danmark
# 2273               Noerregade 6, København 1165 Danmark
# 2274     Kld. Graabroedretorv 5, København 1154 Danmark
# 2282          Blaagaardsgade 35, København 2200 Danmark
# 2284             Stefansgade 47, København 2200 Danmark
# 2285           Hilleroedgade 19, København 2200 Danmark
# 2287              Buelowsvej 40, København 1870 Danmark
# 2296            Vesterbrogade 3, København 1630 Danmark
# 2297       Frederiksborggade 42, København 1360 Danmark
# 2303          Vimmelskaftet 41F, København 1161 Danmark
# 2308             Jernbanegade 7, København 1608 Danmark
#
#                                       Type of food link New price class  \
# 0                                                   NaN          $$$$$$
# 1     <div class="header_links"><a href="/Restaurant...          $$$$$$
# 3                                                   NaN          $$$$$$
# 5     <div class="header_links"><a href="/Restaurant...          $$$$$$
# 8     <div class="header_links"><a href="/Restaurant...          $$$$$$
# 9                                                   NaN          $$$$$$
# 10    <div class="header_links"><a href="/Restaurant...          $$$$$$
# 11    <div class="header_links"><a href="/Restaurant...          $$$$$$
# 12    <div class="header_links"><a href="/Restaurant...               $
# 14                                                  NaN          $$$$$$
# 15    <div class="header_links"><a href="/Restaurant...          $$-$$$
# 18    <div class="header_links"><a href="/Restaurant...          $$-$$$
# 21    <div class="header_links"><a href="/Restaurant...               $
# 25                                                  NaN          $$$$$$
# 26    <div class="header_links"><a href="/Restaurant...          $$-$$$
# 27    <div class="header_links"><a href="/Restaurant...          $$-$$$
# 32    <div class="header_links"><a href="/Restaurant...          $$-$$$
# 36                                                  NaN          $$$$$$
# 37                <div class="header_links">Grill</div>          $$$$$$
# 38                                                  NaN          $$$$$$
# 40    <div class="header_links"><a href="/Restaurant...          $$$$$$
# 41    <div class="header_links"><a href="/Restaurant...          $$$$$$
# 42    <div class="header_links"><a href="/Restaurant...          $$-$$$
# 45    <div class="header_links"><a href="/Restaurant...               $
# 46    <div class="header_links"><a href="/Restaurant...          $$$$$$
# 47                                                  NaN          $$$$$$
# 51    <div class="header_links"><a href="/Restaurant...          $$-$$$
# 52    <div class="header_links"><a href="/Restaurant...          $$-$$$
# 56    <div class="header_links"><a href="/Restaurant...          $$-$$$
# 63    <div class="header_links"><a href="/Restaurant...               $
# ...                                                 ...             ...
# 2177  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2178  <div class="header_links"><a href="/Restaurant...          $$$$$$
# 2180  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2193  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2194  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2201                                                NaN          $$$$$$
# 2207                                                NaN          $$$$$$
# 2224  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2225  <div class="header_links"><a href="/Restaurant...          $$$$$$
# 2230                                                NaN          $$$$$$
# 2231  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2243  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2247  <div class="header_links"><a href="/Restaurant...               $
# 2250  <div class="header_links"><a href="/Restaurant...          $$$$$$
# 2255  <div class="header_links"><a href="/Restaurant...               $
# 2258  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2261  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2263                                                NaN          $$$$$$
# 2264                                                NaN          $$$$$$
# 2266                                                NaN          $$$$$$
# 2273                                                NaN          $$$$$$
# 2274  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2282  <div class="header_links"><a href="/Restaurant...          $$$$$$
# 2284  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2285                                                NaN          $$$$$$
# 2287  <div class="header_links"><a href="/Restaurant...          $$$$$$
# 2296  <div class="header_links"><a href="/Restaurant...          $$$$$$
# 2297  <div class="header_links"><a href="/Restaurant...               $
# 2303  <div class="header_links"><a href="/Restaurant...          $$-$$$
# 2308  <div class="header_links"><a href="/Restaurant...          $$-$$$
#
#       Price class numeric  Reverse ranking on list  Full ranking  \
# 0                      99                  -2148.0             1
# 1                      99                  -2146.0             2
# 3                      99                  -2137.0             4
# 5                      99                  -2103.0             6
# 8                      99                  -2090.0             9
# 9                      99                  -2085.0            10
# 10                     99                  -2070.0            11
# 11                     99                  -2053.0            12
# 12                      1                  -2179.0            13
# 14                     99                  -2159.0            15
# 15                      2                  -2141.0            16
# 18                      2                  -2115.0            19
# 21                      1                   -182.0            22
# 25                     99                  -2171.0            26
# 26                      2                  -2170.0            27
# 27                      2                  -2169.0            28
# 32                      2                  -2153.0            33
# 36                     99                  -2139.0            37
# 37                     99                  -2135.0            38
# 38                     99                  -2114.0            39
# 40                     99                  -2079.0            41
# 41                     99                  -2046.0            42
# 42                      2                  -2040.0            43
# 45                      1                   -181.0            46
# 46                     99                   -180.0            47
# 47                     99                   -177.0            48
# 51                      2                  -2166.0            52
# 52                      2                  -2165.0            53
# 56                      2                  -2155.0            57
# 63                      1                  -2132.0            64
# ...                   ...                      ...           ...
# 2177                    2                      NaN          2178
# 2178                   99                      NaN          2179
# 2180                    2                      NaN          2181
# 2193                    2                      NaN          2194
# 2194                    2                      NaN          2195
# 2201                   99                      NaN          2202
# 2207                   99                      NaN          2208
# 2224                    2                      NaN          2225
# 2225                   99                      NaN          2226
# 2230                   99                      NaN          2231
# 2231                    2                      NaN          2232
# 2243                    2                      NaN          2244
# 2247                    1                      NaN          2248
# 2250                   99                      NaN          2251
# 2255                    1                      NaN          2256
# 2258                    2                      NaN          2259
# 2261                    2                      NaN          2262
# 2263                   99                      NaN          2264
# 2264                   99                      NaN          2265
# 2266                   99                      NaN          2267
# 2273                   99                      NaN          2274
# 2274                    2                      NaN          2275
# 2282                   99                      NaN          2283
# 2284                    2                      NaN          2285
# 2285                   99                      NaN          2286
# 2287                   99                      NaN          2288
# 2296                   99                      NaN          2297
# 2297                    1                      NaN          2298
# 2303                    2                      NaN          2304
# 2308                    2                      NaN          2309
#
#       Distance from Kgs. Nytorv (m) Postal code
# 0                             199.0       2450
# 1                             459.0
# 3                             908.0       1570
# 5                             772.0       1560
# 8                             540.0       1165
# 9                             477.0       1720
# 10                            140.0       1500
# 11                            613.0
# 12                            528.0
# 14                            821.0       2300
# 15                            908.0       1100
# 18                            562.0       2450
# 21                            577.0       1820
# 25                            390.0       2100
# 26                            369.0       1700
# 27                            853.0       2300
# 32                            698.0       2720
# 36                            860.0       2100
# 37                            523.0
# 38                            785.0       1159
# 40                            537.0
# 41                            611.0       1154
# 42                            122.0       2450
# 45                            585.0       2000
# 46                            249.0       2000
# 47                            298.0       1619
# 51                            520.0       1457
# 52                            806.0
# 56                            915.0
# 63                            515.0       1161
# ...                             ...         ...
# 2177                          320.0       2400
# 2178                          745.0         NaN
# 2180                          551.0       1440
# 2193                          983.0       2000
# 2194                          766.0       2000
# 2201                          947.0       2100
# 2207                          248.0       2450
# 2224                          548.0       2100
# 2225                          557.0       1879
# 2230                          271.0       2300
# 2231                          874.0       2300
# 2243                          714.0       2100
# 2247                          299.0       2200
# 2250                          194.0       2200
# 2255                          233.0       2200
# 2258                          596.0       2300
# 2261                          799.0         NaN
# 2263                          759.0       2000
# 2264                          570.0       1620
# 2266                          345.0       1674
# 2273                          492.0       1165
# 2274                          647.0       1154
# 2282                          260.0       2200
# 2284                          138.0       2200
# 2285                          615.0       2200
# 2287                          892.0       1870
# 2296                          998.0       1630
# 2297                          596.0       1360
# 2303                          917.0       1161
# 2308                          596.0       1608
#
# [701 rows x 20 columns]

# %%
# Mean ratings grouped by type of food
bar_df = mod_df.groupby(['Type of food'])['Main rating'].mean()
bar_df = pd.DataFrame(bar_df)

#bar_df.columns = ['Type of food', "Mean rating"]
bar_df2 = mod_df.groupby(['Type of food'])['Main rating'].count()
bar_df2 = pd.DataFrame(bar_df2)

bar_df3 = pd.merge(bar_df, bar_df2, on='Type of food', how='left')
bar_df3 = pd.DataFrame(bar_df3)

bar_df3.columns = ["Mean rating", "Number of restaurants"]
bar_df3.reset_index(inplace=True)

# Only if more than 10 restaurants
bar_df4 = bar_df3.loc[bar_df3['Number of restaurants'] > 10] 
bar_df4 = bar_df4.loc[bar_df3['Type of food'] != "Missing"] 

bar_df4 = bar_df4.sort_values(by=["Mean rating"])
bar_df4
# Out:
#    Type of food  Mean rating  Number of restaurants
# 18       Indisk     3.250000                     14
# 12     Fastfood     3.500000                     13
# 4      Asiatisk     3.740741                     54
# 1    Amerikansk     3.774194                     31
# 20    Italiensk     3.887097                     31
# 5           Bar     3.888889                     18
# 11    Europæisk     3.973333                     75
# 9         Dansk     3.974138                    116
# 7          Café     4.009091                     55

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcdefaults()
fig, ax = plt.subplots()
plt.style.use('ggplot')

# Example data
rests = [bar_df4["Mean rating"]]
y_pos = bar_df4["Type of food"]
performance = bar_df4["Mean rating"]

ax.barh(y_pos, performance, align='center', color = green_color)
#ax.set_yticks(y_pos)
#ax.set_yticklabels("Type of food")
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Mean rating')
ax.set_xlim(3,5)
#ax.set_title('How fast do you want to go today?')
label = [bar_df4["Mean rating"]]


plt.savefig('barplot_type.jpeg')

# %%
# %matplotlib inline
plt.style.use('seaborn')
mod_df.plot(x='Distance from Kgs. Nytorv ()', y='Full ranking', kind='scatter', color=green_color)
plt.show()
plt.savefig('dist_rankin_plot.jpeg')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Distance from Kgs. Nytorv'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-70299c9a0973> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.style.use('seaborn')
# ----> 3 mod_df.plot(x='Distance from Kgs. Nytorv', y='Full ranking', kind='scatter', color=green_color)
#       4 plt.show()
#       5 plt.savefig('dist_rankin_plot.jpeg')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1738         if isinstance(data, ABCDataFrame):
#    1739             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1740                              kind=kind, **kwds)
#    1741         else:
#    1742             raise ValueError("plot kind %r can only be used for data frames"
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     858             # the handling of this argument later
#     859             s = 20
# --> 860         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     861         if is_integer(c) and not self.data.columns.holds_integer():
#     862             c = self.data.columns[c]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     801         if is_integer(y) and not self.data.columns.holds_integer():
#     802             y = self.data.columns[y]
# --> 803         if len(self.data[x]._get_numeric_data()) == 0:
#     804             raise ValueError(self._kind + ' requires x column to be numeric')
#     805         if len(self.data[y]._get_numeric_data()) == 0:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Distance from Kgs. Nytorv'

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
plt.figure(figsize=(10,7.5))
plt.tight_layout()
seabornInstance.distplot(data['Distance from Kgs. Nytorv'], color = green_color)
plt.xlim(0, 15000)
plt.show()

plt.savefig('dist_plot.jpeg')

# %%
import statsmodels.api as sm



reg_df = df_new.loc[mod_df['Price Class Numeric'] != 99] 
reg_df = df_new.loc[mod_df['Full ranking'] != 2000] 


reg1 = sm.OLS(endog=reg_df['Price Class Numeric'], exog=reg_df[['Distance from Kgs. Nytorv', 'Main rating', 'Fransk']], missing='drop')

results = reg1.fit()
print(results.summary())

# %%
dum_df = pd.get_dummies(mod_df['Type of food'])

list_food = set(mod_df['Type of food'])
list34 = []
for i in list_food:
    list34.append(i)
    
df_new = pd.concat([mod_df, dum_df], axis=1)

list34

# %%
reg_df

# %%
X = mod_df["Distance from Kgs. Nytorv"]
y = mod_df["Full ranking"]

import seaborn as sns
fig, ax = plt.subplots()
ax.scatter(X, y, marker='.', color = green_color)
plt.gcf().set_size_inches((15, 7.5))    

ax.plot(np.unique(X),
         np.poly1d(np.polyfit(X, y, 1))(np.unique(X)),
         color='grey')

ax.set_xlabel('Distance from Kgs. Nytorv')
ax.set_ylabel('Ranking')

# %%
# maschinelearning model

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
