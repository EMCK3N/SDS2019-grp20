# %% [markdown]
# ## Importing packages and attributes

# %%
import pandas as pd
from geopy.distance import great_circle

# %% [markdown]
# ## Data Processing

# %% [markdown]
# In this notebook we will process the raw data scraped in our *`TripAdvisor_scraper.ipynb`* We start by loading the CSV file, we created.

# %%
trip_df = pd.read_csv("Tripadvisordata_raw.csv")
trip_df.tail() # prints just to check if the read went well
# Out:
#     God pris  Mad                 Restaurant  Service  Stemning  \
# 95        45   50                  Alchemist       50       NaN
# 96        45   45  District Tonkin - Bánh Mí       40       NaN
# 97        40   45         Restaurant Kanalen       40      45.0
# 98        45   45                    Sidecar       45       NaN
# 99        45   45                        56°       45      50.0
#
#                Location  Number of reviews     Price class Main rating  \
# 95  55.693714,12.613528                 68       --$$$$---         5,0
# 96  55.683544,12.587593                212    --$---------         4,5
# 97   55.67551,12.593101                416       --$$$$---         4,0
# 98  55.687107,12.549084                132  --$$-$$$------         4,5
# 99  55.684166,12.610067                208    --$$$$------         4,5
#
#     Ranking on list  Price range  \
# 95              108        2.501
# 96              113      121.000
# 97              122          NaN
# 98              107      295.000
# 99              120      248.000
#
#                                          Type of food  \
# 95  <div class="header_links"><a href="/Restaurant...
# 96  <div class="header_links"><a href="/Restaurant...
# 97  <div class="header_links"><a href="/Restaurant...
# 98  <div class="header_links"><a href="/Restaurant...
# 99  <div class="header_links"><a href="/Restaurant...
#
#                                              Address
# 95          Refshalevej 173C, København 1432 Danmark
# 96  Dronningens Tvaergade 12, København 1302 Danmark
# 97           Wilders Plads 2, København 1403 Danmark
# 98              Skyttegade 5, København 2200 Danmark
# 99            Krudtløbsvej 8, København 1439 Danmark

# %% [markdown]
# ### Restructuring data

# %%
distance_list = []
Kgs_Nytorv = '55.679977,12.5841893' #longitude and latitude for Kongens Nytorv

#calculating distance from nytorv to the coordinates in the list
def distance(x):
    Start = trip_df["Location"][x]
    Stop = Kgs_Nytorv
    distance_list.append(great_circle(Start, Stop).meters)
    
for x in trip_df.index:
    distance(x)
    
#appending to df 
trip_df["Distance from Kgs. Nytorv (m)"] = distance_list

# %%
trip_df = trip_df.replace(regex=['&amp;'], value='&')
trip_df['Main rating'] = trip_df['Main rating'].replace(regex=[','], value='.')
trip_df['Distance from Kgs. Nytorv (m)'] = trip_df['Distance from Kgs. Nytorv (m)'].round()
trip_df['Good price'] = trip_df['God pris'] / 10
trip_df['Food'] = trip_df['Mad'] / 10
trip_df['Service'] = trip_df['Service'] / 10
trip_df['Atmosphere'] = trip_df['Stemning'] / 10
trip_df = trip_df[['Restaurant', 'Main rating', 'Ranking on list', 'Price range', 'Price class', 'Location', 'Distance from Kgs. Nytorv (m)' , 'Good price', 'Food', 'Service', 'Atmosphere', 'Type of food', 'Number of reviews', 'Address']]

# %%
trip_df.head()
# Out:
#                  Restaurant Main rating  Ranking on list  Price range  \
# 0     Restaurant Grønnegade         4.5               28        664.0
# 1           Basso København         4.5               18        496.0
# 2                  Enomania         4.5                1          NaN
# 3  Restaurant Krebsegaarden         5.0                2        396.0
# 4           The Pescatarian         5.0                6        597.0
#
#          Price class             Location  Distance from Kgs. Nytorv (m)  \
# 0          --$$$$---  55.681705,12.583386                          199.0
# 1  --$$-$$$---------    55.68388,12.58657                          459.0
# 2     --$$-$$$------  55.670773,12.531963                         3431.0
# 3          --$$$$---   55.67872,12.569877                          908.0
# 4       --$$$$------   55.68799,12.596316                         1171.0
#
#    Good price  Food  Service  Atmosphere  \
# 0         4.5   4.5      4.5         4.5
# 1         4.5   4.5      4.5         NaN
# 2         4.5   5.0      5.0         4.5
# 3         4.5   5.0      5.0         4.5
# 4         4.5   5.0      5.0         NaN
#
#                                         Type of food  Number of reviews  \
# 0  <div class="header_links"><a href="/Restaurant...                525
# 1  <div class="header_links"><a href="/Restaurant...                345
# 2  <div class="header_links"><a href="/Restaurant...                245
# 3  <div class="header_links"><a href="/Restaurant...               1311
# 4  <div class="header_links"><a href="/Restaurant...                201
#
#                                              Address
# 0              Grønnegade 39, København 1107 Danmark
# 1   Dronningens Tvaergade 22, København 1302 Danmark
# 2  Vesterbrogade 187, Frederiksberg, København 18...
# 3           Studiestraede 17, København 1455 Danmark
# 4  Amaliegade 49 On the corner of Amaliegade & Es...

# %%
trip_df = trip_df.sort_values(by='Ranking on list', ascending=True)

trip_df.to_csv("Tripadvisordata_200.csv", index=False)
trip_df.head()
# Out:
#                   Restaurant Main rating  Ranking on list  Price range  \
# 22           Grams Lækkerier         5.0                1      101.000
# 2                   Enomania         4.5                1          NaN
# 3   Restaurant Krebsegaarden         5.0                2      396.000
# 6       Mielcke & Hurtigkarl         4.5                2        2.615
# 20            Frederiks Have         4.5                3      536.000
#
#        Price class             Location  Distance from Kgs. Nytorv (m)  \
# 22    --$---------  55.671036,12.562724                         1673.0
# 2   --$$-$$$------  55.670773,12.531963                         3431.0
# 3        --$$$$---   55.67872,12.569877                          908.0
# 6        --$$$$---   55.67468,12.530938                         3390.0
# 20       --$$$$---  55.679256,12.524991                         3712.0
#
#     Good price  Food  Service  Atmosphere  \
# 22         4.5   5.0      5.0         4.5
# 2          4.5   5.0      5.0         4.5
# 3          4.5   5.0      5.0         4.5
# 6          4.5   4.5      4.5         4.5
# 20         4.5   4.5      4.5         4.5
#
#                                          Type of food  Number of reviews  \
# 22  <div class="header_links"><a href="/Restaurant...                721
# 2   <div class="header_links"><a href="/Restaurant...                245
# 3   <div class="header_links"><a href="/Restaurant...               1311
# 6   <div class="header_links"><a href="/Restaurant...                253
# 20  <div class="header_links"><a href="/Restaurant...                529
#
#                                               Address
# 22               Halmtorvet 1, København 1700 Danmark
# 2   Vesterbrogade 187, Frederiksberg, København 18...
# 3            Studiestraede 17, København 1455 Danmark
# 6   Fr.Berg Runddel 1, Frederiksberg, København 20...
# 20  Smallegade 41, Frederiksberg, København 2000 D...
